# %% [markdown]
# # TestFourierTransform

# %% [markdown]
# ## FFT of waveform

# %% [markdown]
# Import necessary modules

# %%
import numpy as np
import scipy as sc
import scipy.fft as scfft
import matplotlib.pyplot as plt
import uproot

# %%
from Functions import *

# %%
CombinedFile, DAQStatFile, HeadersFile, PedestalFile=FilesStRun(23,740)

# %%
print(CombinedFile.keys())
print('---------------')
print(CombinedFile['combined'].show(name_width=60))
# Out:
# ['info;1', 'combined;1']
# ---------------
# name                                                         | typename                 | interpretation
# -------------------------------------------------------------+--------------------------+-------------------------------
# waveforms                                                    | mattak::Waveforms        | AsGroup(<TBranchElement 'wa...
# waveforms/mattak::IWaveforms                                 | (group of TObject:(gr... | AsGroup(<TBranchElement 'ma...
# waveforms/mattak::IWaveforms/TObject                         | (group of fUniqueID:u... | AsGroup(<TBranchElement 'TO...
# waveforms/mattak::IWaveforms/TObject/fUniqueID               | uint32_t                 | AsDtype('>u4')
# waveforms/mattak::IWaveforms/TObject/fBits                   | uint8_t                  | AsDtype('uint8')
# waveforms/mattak::IWaveforms/run_number                      | uint32_t                 | AsDtype('>u4')
# waveforms/mattak::IWaveforms/event_number                    | uint32_t                 | AsDtype('>u4')
# waveforms/mattak::IWaveforms/station_number                  | uint16_t                 | AsDtype('>u2')
# waveforms/mattak::IWaveforms/buffer_length                   | uint16_t                 | AsDtype('>u2')
# waveforms/radiant_data[24][2048]                             | int16_t[24][2048]        | AsDtype("('>i2', (24, 2048))")
# header                                                       | mattak::Header           | AsGroup(<TBranchElement 'he...
# header/TObject                                               | (group of fUniqueID:u... | AsGroup(<TBranchElement 'TO...
# header/TObject/fUniqueID                                     | uint32_t                 | AsDtype('>u4')
# header/TObject/fBits                                         | uint8_t                  | AsDtype('uint8')
# header/run_number                                            | uint32_t                 | AsDtype('>u4')
# header/event_number                                          | uint32_t                 | AsDtype('>u4')
# header/trigger_number                                        | uint32_t                 | AsDtype('>u4')
# header/station_number                                        | uint16_t                 | AsDtype('>u2')
# header/buffer_length                                         | uint16_t                 | AsDtype('>u2')
# header/pretrigger_samples                                    | uint16_t                 | AsDtype('>u2')
# header/readout_time                                          | double                   | AsDtype('>f8')
# header/pps_num                                               | uint32_t                 | AsDtype('>u4')
# header/sysclk                                                | uint32_t                 | AsDtype('>u4')
# header/sysclk_last_pps                                       | uint32_t                 | AsDtype('>u4')
# header/sysclk_last_last_pps                                  | uint32_t                 | AsDtype('>u4')
# header/trigger_time                                          | double                   | AsDtype('>f8')
# header/trigger_info                                          | mattak::TriggerInfo      | AsGroup(<TBranchElement 'tr...
# header/trigger_info/trigger_info.rf_trigger                  | bool                     | AsDtype('bool')
# header/trigger_info/trigger_info.force_trigger               | bool                     | AsDtype('bool')
# header/trigger_info/trigger_info.pps_trigger                 | bool                     | AsDtype('bool')
# header/trigger_info/trigger_info.ext_trigger                 | bool                     | AsDtype('bool')
# header/trigger_info/trigger_info.radiant_trigger             | bool                     | AsDtype('bool')
# header/trigger_info/trigger_info.lt_trigger                  | bool                     | AsDtype('bool')
# header/trigger_info/trigger_info.which_radiant_trigger       | int8_t                   | AsDtype('int8')
# header/trigger_info/trigger_info.radiant_info.channel_mask   | uint32_t                 | AsDtype('>u4')
# header/trigger_info/trigger_info.radiant_info.start_windo... | uint8_t[24][2]           | AsDtype("('u1', (24, 2))")
# header/trigger_info/trigger_info.radiant_info.RF_masks[2]    | uint32_t[2]              | AsDtype("('>u4', (2,))")
# header/trigger_info/trigger_info.radiant_info.RF_ncoinc[2]   | uint8_t[2]               | AsDtype("('u1', (2,))")
# header/trigger_info/trigger_info.radiant_info.RF_window[2]   | uint8_t[2]               | AsDtype("('u1', (2,))")
# header/trigger_info/trigger_info.lt_info.window              | uint8_t                  | AsDtype('uint8')
# header/trigger_info/trigger_info.lt_info.num_coinc           | uint8_t                  | AsDtype('uint8')
# header/trigger_info/trigger_info.lt_info.vppmode             | bool                     | AsDtype('bool')
# daqstatus                                                    | mattak::DAQStatus        | AsGroup(<TBranchElement 'da...
# daqstatus/TObject                                            | (group of fUniqueID:u... | AsGroup(<TBranchElement 'TO...
# daqstatus/TObject/fUniqueID                                  | uint32_t                 | AsDtype('>u4')
# daqstatus/TObject/fBits                                      | uint8_t                  | AsDtype('uint8')
# daqstatus/readout_time_radiant                               | double                   | AsDtype('>f8')
# daqstatus/readout_time_lt                                    | double                   | AsDtype('>f8')
# daqstatus/radiant_thresholds[24]                             | uint32_t[24]             | AsDtype("('>u4', (24,))")
# daqstatus/radiant_scalers[24]                                | uint32_t[24]             | AsDtype("('>u4', (24,))")
# daqstatus/radiant_prescalers_m1[24]                          | uint8_t[24]              | AsDtype("('u1', (24,))")
# daqstatus/radiant_scaler_period                              | float                    | AsDtype('>f4')
# daqstatus/lt_trigger_thresholds[4]                           | uint32_t[4]              | AsDtype("('>u4', (4,))")
# daqstatus/lt_servo_thresholds[4]                             | uint32_t[4]              | AsDtype("('>u4', (4,))")
# daqstatus/lt_1Hz_scalers                                     | mattak::LTScalerGroup    | AsGroup(<TBranchElement 'lt...
# daqstatus/lt_1Hz_scalers/lt_1Hz_scalers.trig_coinc           | uint16_t                 | AsDtype('>u2')
# daqstatus/lt_1Hz_scalers/lt_1Hz_scalers.trig_per_chan[4]     | uint16_t[4]              | AsDtype("('>u2', (4,))")
# daqstatus/lt_1Hz_scalers/lt_1Hz_scalers.servo_coinc          | uint16_t                 | AsDtype('>u2')
# daqstatus/lt_1Hz_scalers/lt_1Hz_scalers.servo_per_chan[4]    | uint16_t[4]              | AsDtype("('>u2', (4,))")
# daqstatus/lt_1Hz_gated_scalers                               | mattak::LTScalerGroup    | AsGroup(<TBranchElement 'lt...
# daqstatus/lt_1Hz_gated_scalers/lt_1Hz_gated_scalers.trig_... | uint16_t                 | AsDtype('>u2')
# daqstatus/lt_1Hz_gated_scalers/lt_1Hz_gated_scalers.trig_... | uint16_t[4]              | AsDtype("('>u2', (4,))")
# daqstatus/lt_1Hz_gated_scalers/lt_1Hz_gated_scalers.servo... | uint16_t                 | AsDtype('>u2')
# daqstatus/lt_1Hz_gated_scalers/lt_1Hz_gated_scalers.servo... | uint16_t[4]              | AsDtype("('>u2', (4,))")
# daqstatus/lt_100Hz_scalers                                   | mattak::LTScalerGroup    | AsGroup(<TBranchElement 'lt...
# daqstatus/lt_100Hz_scalers/lt_100Hz_scalers.trig_coinc       | uint16_t                 | AsDtype('>u2')
# daqstatus/lt_100Hz_scalers/lt_100Hz_scalers.trig_per_chan[4] | uint16_t[4]              | AsDtype("('>u2', (4,))")
# daqstatus/lt_100Hz_scalers/lt_100Hz_scalers.servo_coinc      | uint16_t                 | AsDtype('>u2')
# daqstatus/lt_100Hz_scalers/lt_100Hz_scalers.servo_per_cha... | uint16_t[4]              | AsDtype("('>u2', (4,))")
# daqstatus/lt_ncycles                                         | uint64_t                 | AsDtype('>u8')
# daqstatus/lt_scaler_counter                                  | uint16_t                 | AsDtype('>u2')
# daqstatus/station_number                                     | uint8_t                  | AsDtype('uint8')
# None

# %%
TimeTrace(23,13,740,16,Amplitude="V")
TimeTraceFFT(23,13,740,16,Amplitude="V",LogScale=True)

# %%
CmbFile=GetCombinedFile(22,712)
CmbFile['combined'].show()
# Out:
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# waveforms            | mattak::Waveforms        | AsGroup(<TBranchElement 'wa...
# waveforms/TObject    | (group of fUniqueID:u... | AsGroup(<TBranchElement 'TO...
# waveforms/TObject... | uint32_t                 | AsDtype('>u4')
# waveforms/TObject... | uint8_t                  | AsDtype('uint8')
# waveforms/run_number | uint32_t                 | AsDtype('>u4')
# waveforms/event_n... | uint32_t                 | AsDtype('>u4')
# waveforms/station... | uint16_t                 | AsDtype('>u2')
# waveforms/buffer_... | uint16_t                 | AsDtype('>u2')
# waveforms/radiant... | int16_t[24][2048]        | AsDtype("('>i2', (24, 2048))")
# header               | mattak::Header           | AsGroup(<TBranchElement 'he...
# header/TObject       | (group of fUniqueID:u... | AsGroup(<TBranchElement 'TO...
# header/TObject/fU... | uint32_t                 | AsDtype('>u4')
# header/TObject/fBits | uint8_t                  | AsDtype('uint8')
# header/run_number    | uint32_t                 | AsDtype('>u4')
# header/event_number  | uint32_t                 | AsDtype('>u4')
# header/trigger_nu... | uint32_t                 | AsDtype('>u4')
# header/station_nu... | uint16_t                 | AsDtype('>u2')
# header/buffer_length | uint16_t                 | AsDtype('>u2')
# header/pretrigger... | uint16_t                 | AsDtype('>u2')
# header/readout_time  | double                   | AsDtype('>f8')
# header/pps_num       | uint32_t                 | AsDtype('>u4')
# header/sysclk        | uint32_t                 | AsDtype('>u4')
# header/sysclk_las... | uint32_t                 | AsDtype('>u4')
# header/sysclk_las... | uint32_t                 | AsDtype('>u4')
# header/trigger_time  | double                   | AsDtype('>f8')
# header/trigger_info  | mattak::TriggerInfo      | AsGroup(<TBranchElement 'tr...
# header/trigger_in... | bool                     | AsDtype('bool')
# header/trigger_in... | bool                     | AsDtype('bool')
# header/trigger_in... | bool                     | AsDtype('bool')
# header/trigger_in... | bool                     | AsDtype('bool')
# header/trigger_in... | bool                     | AsDtype('bool')
# header/trigger_in... | bool                     | AsDtype('bool')
# header/trigger_in... | bool                     | AsDtype('bool')
# header/trigger_in... | uint32_t                 | AsDtype('>u4')
# header/trigger_in... | uint8_t[24][2]           | AsDtype("('u1', (24, 2))")
# header/trigger_in... | uint32_t[2]              | AsDtype("('>u4', (2,))")
# header/trigger_in... | uint8_t[2]               | AsDtype("('u1', (2,))")
# header/trigger_in... | uint8_t[2]               | AsDtype("('u1', (2,))")
# header/trigger_in... | uint8_t                  | AsDtype('uint8')
# header/trigger_in... | uint8_t                  | AsDtype('uint8')
# header/trigger_in... | bool                     | AsDtype('bool')
# daqstatus            | mattak::DAQStatus        | AsGroup(<TBranchElement 'da...
# daqstatus/TObject    | (group of fUniqueID:u... | AsGroup(<TBranchElement 'TO...
# daqstatus/TObject... | uint32_t                 | AsDtype('>u4')
# daqstatus/TObject... | uint8_t                  | AsDtype('uint8')
# daqstatus/readout... | double                   | AsDtype('>f8')
# daqstatus/readout... | double                   | AsDtype('>f8')
# daqstatus/radiant... | uint32_t[24]             | AsDtype("('>u4', (24,))")
# daqstatus/radiant... | uint32_t[24]             | AsDtype("('>u4', (24,))")
# daqstatus/radiant... | uint8_t[24]              | AsDtype("('u1', (24,))")
# daqstatus/radiant... | float                    | AsDtype('>f4')
# daqstatus/lt_trig... | uint32_t[4]              | AsDtype("('>u4', (4,))")
# daqstatus/lt_serv... | uint32_t[4]              | AsDtype("('>u4', (4,))")
# daqstatus/lt_1Hz_... | mattak::LTScalerGroup    | AsGroup(<TBranchElement 'lt...
# daqstatus/lt_1Hz_... | uint16_t                 | AsDtype('>u2')
# daqstatus/lt_1Hz_... | uint16_t[4]              | AsDtype("('>u2', (4,))")
# daqstatus/lt_1Hz_... | uint16_t                 | AsDtype('>u2')
# daqstatus/lt_1Hz_... | uint16_t[4]              | AsDtype("('>u2', (4,))")
# daqstatus/lt_1Hz_... | mattak::LTScalerGroup    | AsGroup(<TBranchElement 'lt...
# daqstatus/lt_1Hz_... | uint16_t                 | AsDtype('>u2')
# daqstatus/lt_1Hz_... | uint16_t[4]              | AsDtype("('>u2', (4,))")
# daqstatus/lt_1Hz_... | uint16_t                 | AsDtype('>u2')
# daqstatus/lt_1Hz_... | uint16_t[4]              | AsDtype("('>u2', (4,))")
# daqstatus/lt_100H... | mattak::LTScalerGroup    | AsGroup(<TBranchElement 'lt...
# daqstatus/lt_100H... | uint16_t                 | AsDtype('>u2')
# daqstatus/lt_100H... | uint16_t[4]              | AsDtype("('>u2', (4,))")
# daqstatus/lt_100H... | uint16_t                 | AsDtype('>u2')
# daqstatus/lt_100H... | uint16_t[4]              | AsDtype("('>u2', (4,))")
# daqstatus/lt_ncycles | uint64_t                 | AsDtype('>u8')
# daqstatus/lt_scal... | uint16_t                 | AsDtype('>u2')
# daqstatus/station... | uint8_t                  | AsDtype('uint8')

# %% [markdown]
# def FilesStRun(StNr,RunNr):
#     path=Path(StNr,RunNr)
#     CombinedFile=uproot.open(path+"/combined.root")
#     DAQStatFile=uproot.open(path+"/daqstatus.root")
#     HeadersFile=uproot.open(path+"/headers.root")
#     PedestalFile=uproot.open(path+"/pedestal.root")
#     return CombinedFile, DAQStatFile, HeadersFile, PedestalFile

# %% [markdown]
# def DailyVoltAvg(StNr,ChNr,Runs,NBins=24,ZeroAvg=True,TimeFormat="LST",Triggers=(5,5,5,5),StdCut=-1,FFTFilter=True,Lowpass=False):
#     """
#     Plots the Average V_RMS as a function of time of the day.
#     Parameters:
#     StNr,ChNr,Runs=Station number, channel number, list of runs
#     NBins=amount of bins to divide the full day in
#     ZeroAvg=Boolean: if true, the timetraces will firs tbe zero averaged
#     Lowpass= Boolean: if true, a butterworth lowpass filter will be applied in order to maintain only galactic noise dominated frequencies
#     FFTFilter=Boolean: if true, applies a Notch filter to all frequency spectra to cut out frequencies which have shown to be potentially problematic
#     TimeFormat= String: Dictates what timeformat the x-axis will be in. Options: "LST": local sidereal time, "LT": Local time & "UTC": UTC time
#     Triggers=tupel of flags to dictate which triggers are allowed in the analysis. Events with different triggers are not used (0=has to be absent, 1=has to be present, anything else=both 0 and 1 can be used for analysis)
#     StdCut=if larger than zero, all VRMS outliers above StdCut standard variations will be cut out of the analysis
#     """
#     (has_rf,has_ext,has_pps,has_soft)=Triggers
#     NEvs=0
#     EventRMS=np.array([]) #Array to store V_RMS value of each event
#     EventTime=np.array([])#Array to store timestamp of each event
#     #for (Run, EvNr) in TriggerFilterAlt(StNr, ChNr, Runs,has_rf,has_ext,has_pps,has_soft):
#     for (Run,EvNr) in TriggerFilterAlt(StNr, ChNr, Runs,has_rf,has_ext,has_pps,has_soft):
#         path=Path(StNr,Run)
#         #if os.path.isdir(path+"/combined.root"):
#         if os.path.isfile(path+"/combined.root") and os.path.isfile(path+"/daqstatus.root"):
#             NEvs+=1
#
#             CombinedFile, DAQStatFile, HeadersFile, PedestalFile=FilesStRun(StNr,Run)
#             RadiantData=CombinedFile['combined']['waveforms']['radiant_data[24][2048]'].array(library='np')
#             EventNrs=CombinedFile['combined']['waveforms']['event_number'].array(library="np")
#             TriggerTimes=CombinedFile['combined']['header']["trigger_time"].array(library='np')
#
#             EvIndex=np.where(EventNrs==EvNr)[0][0]
#             VoltageTrace=ADCtoVoltage(RadiantData[EvIndex][ChNr]) #The timetrace data in voltage
#             if ZeroAvg==True:
#                 Vmean=np.mean(VoltageTrace)
#                 VoltageTrace-=Vmean
#                 #EventRMS=np.append(EventRMS,np.sqrt(np.mean([(V-Vmean)**2 for V in ADCtoVoltage(RadiantData[EvIndex][ChNr])])))
#             if FFTFilter or Lowpass:
#                 sampling_rate=3.2 * (10**9) #Sampling rate in Hertz according to the python file of NuRadioReco.modules.io.rno_g
#                 TimeStep=1/sampling_rate #Time between two samples
#                 SamplingTimes=np.arange(0,len(RadiantData[0][0])*TimeStep,TimeStep)
#                 freq=scfft.fftfreq(len(SamplingTimes),(SamplingTimes[-1]-SamplingTimes[0])/len(SamplingTimes))
#                 freq=np.fft.fftshift(freq)
#                 TotalFilter=np.ones(len(freq))
#                 if FFTFilter:
#                     TotalFilter=np.multiply(TotalFilter,NotchFilters([403*10**6,120*10**6,807*10**6,1197*10**6],75,freq,sampling_rate))
#                 if Lowpass:
#                     CritFreq=110*10**6
#                     TotalFilter=np.multiply(TotalFilter,LowpassButter(CritFreq,20,freq))
#                 FFT=scfft.fft(VoltageTrace)
#                 FFT=np.fft.fftshift(FFT)
#                 FFT=np.array([FFT[i]*TotalFilter[i] for i in range(len(freq))])
#                 VoltageTrace=np.abs(scfft.ifft(FFT))
#
#             EventRMS=np.append(EventRMS,np.sqrt(np.mean([V**2 for V in VoltageTrace])))
#
#             if TimeFormat=="LST":
#                 EventTime=np.append(EventTime,LST(TriggerTimes,EvIndex))
#             elif TimeFormat=="LT": #Greenland Timezone is UTC-3
#                 EventTime=np.append(EventTime,(UTC(TriggerTimes,EvIndex)-3)%24)
#             else:
#                 print("Please enter a valid TimeFormat")
#                 return
